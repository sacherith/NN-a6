# %% [markdown]
# 1.In class programming:
# 1. Use the use case in the class:
# a. Add more Dense layers to the existing code and check how the accuracy changes.
# 2. Change the data source to Breast Cancer dataset * available in the source code folder and make required
# changes. Report accuracy of the model.
# 3. Normalize the data before feeding the data to the model and check how the normalization change your
# accuracy (code given below).
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# Breast Cancer dataset is designated to predict if a patient has Malignant (M) or Benign = B cancer

# %% [markdown]
# Use Case Description:
#
# Predicting the diabetes disease
# Programming elements:
# Keras Basics
#
# In class programming:
#
# 1.Use the use case in the class:
#
# a. Add more Dense layers to the existing code and check how the accuracy changes.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation  # Updated import

# Load the diabetes dataset and convert it to a NumPy array
dataset = pd.read_csv("/content/diabetes.csv", header=None).values

# Split the dataset into input features (X) and the target variable (Y)
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:, 0:8], dataset[:, 8], test_size=0.25, random_state=87)

# Set a random seed for reproducibility
np.random.seed(155)

# Create a Sequential model
my_first_nn = Sequential()

# Add a hidden layer with 20 neurons and ReLU activation function
my_first_nn.add(Dense(20, input_dim=8, activation='relu'))

# Add an output layer with a single neuron and a sigmoid activation function for binary classification
my_first_nn.add(Dense(1, activation='sigmoid'))

# Compile the model with binary cross-entropy loss and the Adam optimizer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit (train) the model on the training data for 100 epochs
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)

# Print a summary of the model architecture
print(my_first_nn.summary())

# Evaluate the model on the test data and print the loss and accuracy
loss, accuracy = my_first_nn.evaluate(X_test, Y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 3ms/step - loss: 10.3753 - accuracy: 0.5347
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 5.8453 - accuracy: 0.6267
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.6202 - accuracy: 0.6215
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.4822 - accuracy: 0.5747
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.3175 - accuracy: 0.6007
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.1942 - accuracy: 0.6163
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0756 - accuracy: 0.5990
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0327 - accuracy: 0.6181
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9749 - accuracy: 0.6076
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9618 - accuracy: 0.6094
# Epoch 11/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.8995 - accuracy: 0.6458
# Epoch 12/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8632 - accuracy: 0.6285
# Epoch 13/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8492 - accuracy: 0.6458
# Epoch 14/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8268 - accuracy: 0.6510
# Epoch 15/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8064 - accuracy: 0.6597
# Epoch 16/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8237 - accuracy: 0.6302
# Epoch 17/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7804 - accuracy: 0.6441
# Epoch 18/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7421 - accuracy: 0.6580
# Epoch 19/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7317 - accuracy: 0.6684
# Epoch 20/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7286 - accuracy: 0.6736
# Epoch 21/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7134 - accuracy: 0.6632
# Epoch 22/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6999 - accuracy: 0.6771
# Epoch 23/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8036 - accuracy: 0.6458
# Epoch 24/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7198 - accuracy: 0.6823
# Epoch 25/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6736 - accuracy: 0.6858
# Epoch 26/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6889 - accuracy: 0.6701
# Epoch 27/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6694 - accuracy: 0.6840
# Epoch 28/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6532 - accuracy: 0.7066
# Epoch 29/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6441 - accuracy: 0.6997
# Epoch 30/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6395 - accuracy: 0.6892
# Epoch 31/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6674 - accuracy: 0.6684
# Epoch 32/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6507 - accuracy: 0.6736
# Epoch 33/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6496 - accuracy: 0.6719
# Epoch 34/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7072 - accuracy: 0.6892
# Epoch 35/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6670 - accuracy: 0.6597
# Epoch 36/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6263 - accuracy: 0.7049
# Epoch 37/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6158 - accuracy: 0.6979
# Epoch 38/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6353 - accuracy: 0.6858
# Epoch 39/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6330 - accuracy: 0.7049
# Epoch 40/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6214 - accuracy: 0.7031
# Epoch 41/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6089 - accuracy: 0.7118
# Epoch 42/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6273 - accuracy: 0.7031
# Epoch 43/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6197 - accuracy: 0.6840
# Epoch 44/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6064 - accuracy: 0.7257
# Epoch 45/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6106 - accuracy: 0.7240
# Epoch 46/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6069 - accuracy: 0.7014
# Epoch 47/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6136 - accuracy: 0.7031
# Epoch 48/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6029 - accuracy: 0.7031
# Epoch 49/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6482 - accuracy: 0.6858
# Epoch 50/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6127 - accuracy: 0.6858
# Epoch 51/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6210 - accuracy: 0.7014
# Epoch 52/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5965 - accuracy: 0.7101
# Epoch 53/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6228 - accuracy: 0.7014
# Epoch 54/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5940 - accuracy: 0.7205
# Epoch 55/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5954 - accuracy: 0.7309
# Epoch 56/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6003 - accuracy: 0.6944
# Epoch 57/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6326 - accuracy: 0.7101
# Epoch 58/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6129 - accuracy: 0.6962
# Epoch 59/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6011 - accuracy: 0.7101
# Epoch 60/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5976 - accuracy: 0.7049
# Epoch 61/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5963 - accuracy: 0.7222
# Epoch 62/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6103 - accuracy: 0.7170
# Epoch 63/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5886 - accuracy: 0.7188
# Epoch 64/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6126 - accuracy: 0.6753
# Epoch 65/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5970 - accuracy: 0.7240
# Epoch 66/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6439 - accuracy: 0.6910
# Epoch 67/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5792 - accuracy: 0.7274
# Epoch 68/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5957 - accuracy: 0.6997
# Epoch 69/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5814 - accuracy: 0.7170
# Epoch 70/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5957 - accuracy: 0.7031
# Epoch 71/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5638 - accuracy: 0.7257
# Epoch 72/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5800 - accuracy: 0.7101
# Epoch 73/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5733 - accuracy: 0.7170
# Epoch 74/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5866 - accuracy: 0.6944
# Epoch 75/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5747 - accuracy: 0.7326
# Epoch 76/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5747 - accuracy: 0.7309
# Epoch 77/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5710 - accuracy: 0.7135
# Epoch 78/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5874 - accuracy: 0.7222
# Epoch 79/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6011 - accuracy: 0.7101
# Epoch 80/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5817 - accuracy: 0.7205
# Epoch 81/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5723 - accuracy: 0.7240
# Epoch 82/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5695 - accuracy: 0.7431
# Epoch 83/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6000 - accuracy: 0.7066
# Epoch 84/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5938 - accuracy: 0.7170
# Epoch 85/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5640 - accuracy: 0.7101
# Epoch 86/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5556 - accuracy: 0.7361
# Epoch 87/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5859 - accuracy: 0.6962
# Epoch 88/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5590 - accuracy: 0.7274
# Epoch 89/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5541 - accuracy: 0.7292
# Epoch 90/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5572 - accuracy: 0.7326
# Epoch 91/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5659 - accuracy: 0.7274
# Epoch 92/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5567 - accuracy: 0.7274
# Epoch 93/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5628 - accuracy: 0.7188
# Epoch 94/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5480 - accuracy: 0.7326
# Epoch 95/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5671 - accuracy: 0.7222
# Epoch 96/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5997 - accuracy: 0.7031
# Epoch 97/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5802 - accuracy: 0.7135
# Epoch 98/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.5672 - accuracy: 0.7188
# Epoch 99/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.
100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1794 - acc: 0.9296
# Epoch 30/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1874 - acc: 0.9366
# Epoch 31/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1799 - acc: 0.9296
# Epoch 32/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2030 - acc: 0.9202
# Epoch 33/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1754 - acc: 0.9343
# Epoch 34/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1870 - acc: 0.9272
# Epoch 35/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1727 - acc: 0.9296
# Epoch 36/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1946 - acc: 0.9296
# Epoch 37/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1790 - acc: 0.9319
# Epoch 38/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1641 - acc: 0.9319
# Epoch 39/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1662 - acc: 0.9272
# Epoch 40/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1689 - acc: 0.9343
# Epoch 41/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1647 - acc: 0.9343
# Epoch 42/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1835 - acc: 0.9249
# Epoch 43/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1647 - acc: 0.9272
# Epoch 44/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1586 - acc: 0.9343
# Epoch 45/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1634 - acc: 0.9343
# Epoch 46/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1548 - acc: 0.9296
# Epoch 47/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1640 - acc: 0.9319
# Epoch 48/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1558 - acc: 0.9319
# Epoch 49/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1624 - acc: 0.9319
# Epoch 50/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1775 - acc: 0.9390
# Epoch 51/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1971 - acc: 0.9249
# Epoch 52/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1807 - acc: 0.9296
# Epoch 53/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2489 - acc: 0.9131
# Epoch 54/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1642 - acc: 0.9296
# Epoch 55/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1533 - acc: 0.9296
# Epoch 56/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1629 - acc: 0.9296
# Epoch 57/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1535 - acc: 0.9343
# Epoch 58/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1831 - acc: 0.9249
# Epoch 59/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1579 - acc: 0.9319
# Epoch 60/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1557 - acc: 0.9343
# Epoch 61/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1507 - acc: 0.9296
# Epoch 62/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1551 - acc: 0.9296
# Epoch 63/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1573 - acc: 0.9390
# Epoch 64/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1629 - acc: 0.9178
# Epoch 65/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1469 - acc: 0.9343
# Epoch 66/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1539 - acc: 0.9343
# Epoch 67/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1592 - acc: 0.9272
# Epoch 68/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1694 - acc: 0.9296
# Epoch 69/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1593 - acc: 0.9343
# Epoch 70/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1587 - acc: 0.9319
# Epoch 71/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1422 - acc: 0.9390
# Epoch 72/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1434 - acc: 0.9343
# Epoch 73/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1483 - acc: 0.9343
# Epoch 74/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1420 - acc: 0.9437
# Epoch 75/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1485 - acc: 0.9319
# Epoch 76/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1674 - acc: 0.9343
# Epoch 77/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1439 - acc: 0.9366
# Epoch 78/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1526 - acc: 0.9390
# Epoch 79/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1415 - acc: 0.9437
# Epoch 80/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1434 - acc: 0.9366
# Epoch 81/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1482 - acc: 0.9296
# Epoch 82/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1729 - acc: 0.9460
# Epoch 83/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1615 - acc: 0.9319
# Epoch 84/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2293 - acc: 0.9202
# Epoch 85/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1676 - acc: 0.9390
# Epoch 86/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2303 - acc: 0.9155
# Epoch 87/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1505 - acc: 0.9319
# Epoch 88/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1347 - acc: 0.9390
# Epoch 89/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1392 - acc: 0.9413
# Epoch 90/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1330 - acc: 0.9413
# Epoch 91/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1486 - acc: 0.9366
# Epoch 92/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1391 - acc: 0.9390
# Epoch 93/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1505 - acc: 0.9413
# Epoch 94/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2365 - acc: 0.9202
# Epoch 95/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1809 - acc: 0.9296
# Epoch 96/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1305 - acc: 0.9390
# Epoch 97/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1293 - acc: 0.9413
# Epoch 98/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1419 - acc: 0.9366
# Epoch 99/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1325 - acc: 0.9460
# Epoch 100/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1382 - acc: 0.9437
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 20)                620
#
#  dense_5 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 641 (2.50 KB)
# Trainable params: 641 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1595 - acc: 0.9510
# [0.1595267653465271, 0.9510489702224731]

# %% [markdown]
# 2.In class programming:
# Use Image Classification on the hand written digits data set (mnist)
# 1. Plot the loss and accuracy for both training data and validation data using the history object in the source
# code.
# 2. Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model
# on that single image.
# 3. We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the
# activation to tanh or sigmoid and see what happens.
# 4. Run the same code without scaling the images and check the performance?

# %% [markdown]
# Use Image Classification on the hand written digits data set (mnist)
# 1. Plot the loss and accuracy for both training data and validation data using the history object in the source
# code.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# Load the MNIST dataset
(x_train, y_train), (x_val, y_val) = mnist.load_data()

# Preprocess the data
x_train, x_val = x_train / 255.0, x_val / 255.0  # Normalize pixel values to [0, 1]

# Define the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),  # Flatten the 28x28 input images
    tf.keras.layers.Dense(128, activation='relu'),  # Fully connected layer with ReLU activation
    tf.keras.layers.Dropout(0.2),  # Dropout layer to prevent overfitting
    tf.keras.layers.Dense(10)  # Output layer with 10 units for 10 classes (digits 0-9)
])

# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_val, y_val))

# Plot the loss and accuracy for both training and validation data
plt.figure(figsize=(12, 4))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2991 - accuracy: 0.9132 - val_loss: 0.1449 - val_accuracy: 0.9564
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1441 - accuracy: 0.9577 - val_loss: 0.0986 - val_accuracy: 0.9698
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1078 - accuracy: 0.9668 - val_loss: 0.0850 - val_accuracy: 0.9741
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0882 - accuracy: 0.9728 - val_loss: 0.0785 - val_accuracy: 0.9759
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0764 - accuracy: 0.9756 - val_loss: 0.0796 - val_accuracy: 0.9761
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0655 - accuracy: 0.9793 - val_loss: 0.0705 - val_accuracy: 0.9793
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0591 - accuracy: 0.9815 - val_loss: 0.0673 - val_accuracy: 0.9787
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0564 - accuracy: 0.9818 - val_loss: 0.0700 - val_accuracy: 0.9800
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0484 - accuracy: 0.9845 - val_loss: 0.0732 - val_accuracy: 0.9801
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0445 - accuracy: 0.9852 - val_loss: 0.0696 - val_accuracy: 0.9793

# %% [markdown]
# 2. Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model
# on that single image

# %%
import numpy as np

# Select a random image from the test data
index = np.random.randint(0, len(x_val))
sample_image = x_val[index]
true_label = y_val[index]

# Reshape the image to match the model's input shape
sample_image = np.expand_dims(sample_image, axis=0)

# Perform inference
predictions = model.predict(sample_image)

# Get the predicted label (class) for the image
predicted_label = np.argmax(predictions)

# Define a list of class labels (digits 0-9)
class_labels = [str(i) for i in range(10)]

# Plot the selected image
plt.figure(figsize=(4, 4))
plt.imshow(sample_image[0], cmap='gray')
plt.title(f"True Label: {class_labels[true_label]}\nPredicted Label: {class_labels[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 108ms/step

# %% [markdown]
# 3. We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the
# activation to tanh or sigmoid and see what happens.

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))
# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.0698, Test accuracy: 0.9816
# 1 hidden layer with sigmoid - Test loss: 0.0600, Test accuracy: 0.9810
# 2 hidden layers with tanh - Test loss: 0.0642, Test accuracy: 0.9821
# 2 hidden layers with sigmoid - Test loss: 0.0627, Test accuracy: 0.9825

# %% [markdown]
# 4. Run the same code without scaling the images and check the performance?

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))
# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))
# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.1855, Test accuracy: 0.9446
# 1 hidden layer with sigmoid - Test loss: 0.1463, Test accuracy: 0.9566
# 2 hidden layers with tanh - Test loss: 0.1372, Test accuracy: 0.9570
# 2 hidden layers with sigmoid - Test loss: 0.1115, Test accuracy: 0.9669
